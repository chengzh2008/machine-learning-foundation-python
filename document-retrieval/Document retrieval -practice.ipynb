# %% [markdown]
# #Document retrieval from wikipedia data
#
# #Fire up GraphLab Create

# %%
import graphlab

# %% [markdown]
# #Load some text data - from wikipedia, pages on people

# %%
people = graphlab.SFrame('people_wiki.gl/')
# Out:
# [INFO] This trial license of GraphLab Create is assigned to chengzh2008@gmail.com and will expire on October 23, 2015. Please contact trial@dato.com for licensing options or to request a free non-commercial license for personal or academic use.
#
# [INFO] Start server at: ipc:///tmp/graphlab_server-44881 - Server binary: /Users/xiaoyazi/anaconda/lib/python2.7/site-packages/graphlab/unity_server - Server log: /tmp/graphlab_server_1444190236.log
# [INFO] GraphLab Server Version: 1.6.1

# %% [markdown]
# Data contains:  link to wikipedia article, name of person, text of article.

# %%
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+
# |              text             |
# +-------------------------------+
# ...

# %%
len(people)
# Out:
# 59071

# %% [markdown]
# #Explore the dataset and checkout the text it contains
#
# ##Exploring the entry for president Obama

# %%
john = people[people['name'] == 'Elton John']
victoria = people[people['name'] == 'Victoria Beckham']
paul = people[people['name'] == 'Paul McCartney']

# %% [markdown]
# ##Exploring the entry for actor George Clooney

# %% [markdown]
# #Get the word counts for Obama article

# %%
john['word_count'] = graphlab.text_analytics.count_words(john['text'])
victoria['word_count'] = graphlab.text_analytics.count_words(victoria['text'])
paul['word_count'] = graphlab.text_analytics.count_words(paul['text'])
john_table = john[['word_count']].stack('word_count', new_column_name = ['word', 'count']).sort('count',ascending=False)
victoria_table = victoria[['word_count']].stack('word_count', new_column_name = ['word', 'count']).sort('count',ascending=False)
victoria_table.head()
paul_table = paul[['word_count']].stack('word_count', new_column_name = ['word', 'count']).sort('count',ascending=False)
paul_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +------+-------+
# | word | count |
# +------+-------+
# | and  |   17  |
# |  of  |   15  |
# | the  |   14  |
# |  in  |   8   |
# | has  |   7   |
# |  as  |   7   |
# | his  |   5   |
# | one  |   5   |
# |  he  |   5   |
# |  a   |   5   |
# +------+-------+
# [10 rows x 2 columns]

# %%
victoria_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +---------+-------+
# |   word  | count |
# +---------+-------+
# |   the   |   19  |
# |    in   |   12  |
# |   and   |   12  |
# | beckham |   8   |
# |    to   |   6   |
# |    of   |   6   |
# |    a    |   5   |
# |   she   |   5   |
# | fashion |   5   |
# |   was   |   4   |
# +---------+-------+
# [10 rows x 2 columns]

# %%
paul_table.head()
# Out:
# Columns:
# 	word	str
# 	count	int
#
# Rows: 10
#
# Data:
# +------+-------+
# | word | count |
# +------+-------+
# | and  |   17  |
# |  of  |   15  |
# | the  |   14  |
# |  in  |   8   |
# | has  |   7   |
# |  as  |   7   |
# | his  |   5   |
# | one  |   5   |
# |  he  |   5   |
# |  a   |   5   |
# +------+-------+
# [10 rows x 2 columns]

# %% [markdown]
# #Compute TF-IDF for the corpus
#
# To give more weight to informative words, we weigh them by their TF-IDF scores.

# %%
people['word_count'] = graphlab.text_analytics.count_words(people['text'])
people.head()
# Out:
# Columns:
# 	URI	str
# 	name	str
# 	text	str
# 	word_count	dict
#
# Rows: 10
#
# Data:
# +-------------------------------+---------------------+
# |              URI              |         name        |
# +-------------------------------+---------------------+
# | <http://dbpedia.org/resour... |    Digby Morrell    |
# | <http://dbpedia.org/resour... |    Alfred J. Lewy   |
# | <http://dbpedia.org/resour... |    Harpdog Brown    |
# | <http://dbpedia.org/resour... | Franz Rottensteiner |
# | <http://dbpedia.org/resour... |        G-Enka       |
# | <http://dbpedia.org/resour... |    Sam Henderson    |
# | <http://dbpedia.org/resour... |    Aaron LaCrate    |
# | <http://dbpedia.org/resour... |   Trevor Ferguson   |
# | <http://dbpedia.org/resour... |     Grant Nelson    |
# | <http://dbpedia.org/resour... |     Cathy Caruth    |
# +-------------------------------+---------------------+
# +-------------------------------+-------------------------------+
# ...

# %%
tfidf = graphlab.text_analytics.tf_idf(people['word_count'])
tfidf
# Out:
# Columns:
# 	docs	dict
#
# Rows: 59071
#
# Data:
# +-------------------------------+
# |              docs             |
# +-------------------------------+
# | {'selection': 3.8365785530... |
# | {'precise': 6.443200606955... |
# | {'just': 2.700729968710864... |
# | {'all': 1.6431112434912472... |
# | {'they': 1.899340117819389... |
# | {'currently': 1.6370889691... |
# | {'exclusive': 10.455187230... |
# | {'taxi': 6.052021456094502... |
# | {'houston': 3.935505942157... |
# | {'phenomenon': 5.750053426... |
# +-------------------------------+
# [59071 rows x 1 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
people['tfidf'] = tfidf['docs']

# %% [markdown]
# ##Examine the TF-IDF for the Obama article

# %%
john_1 = people[people['name'] == 'Elton John']
victoria_1 = people[people['name'] == 'Victoria Beckham']
paul_1 = people[people['name'] == 'Paul McCartney']

# %%
john_1[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 255
#
# Data:
# +---------------+---------------+
# |      word     |     tfidf     |
# +---------------+---------------+
# |    furnish    |  18.38947184  |
# |     elton     |  17.48232027  |
# |   billboard   | 17.3036809575 |
# |      john     | 13.9393127924 |
# |  songwriters  |  11.250406447 |
# | tonightcandle | 10.9864953892 |
# |  overallelton | 10.9864953892 |
# |    19702000   | 10.2933482087 |
# |   fivedecade  | 10.2933482087 |
# |      aids     |  10.262846934 |
# +---------------+---------------+
# [255 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
victoria_1[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 175
#
# Data:
# +--------------+---------------+
# |     word     |     tfidf     |
# +--------------+---------------+
# |   beckham    | 56.9223550265 |
# |   fashion    | 21.1652873531 |
# |    spice     | 19.9280699021 |
# |   victoria   | 15.7663610884 |
# |   designer   | 15.6191472125 |
# | chartbeckham | 10.9864953892 |
# | lowerpriced  | 10.9864953892 |
# |    label     | 9.90513433711 |
# |   clamour    | 9.88788310056 |
# |   topmodel   | 9.60020102811 |
# +--------------+---------------+
# [175 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %%
paul_1[['tfidf']].stack('tfidf',new_column_name=['word','tfidf']).sort('tfidf',ascending=False)
# Out:
# Columns:
# 	word	str
# 	tfidf	float
#
# Rows: 162
#
# Data:
# +----------------+---------------+
# |      word      |     tfidf     |
# +----------------+---------------+
# |   mccartney    | 25.3301401563 |
# |     lennon     | 18.9691688853 |
# |    beatles     | 16.5050953672 |
# |     starr      | 12.2533659697 |
# |      solo      | 11.3545130372 |
# | lainemccartney | 10.9864953892 |
# | musicmccartney | 10.9864953892 |
# |    harrison    | 10.6820969832 |
# |      mbes      | 10.2933482087 |
# |     wings      | 10.1622670823 |
# +----------------+---------------+
# [162 rows x 2 columns]
# Note: Only the head of the SFrame is printed.
# You can use print_rows(num_rows=m, num_columns=n) to print more rows and columns.

# %% [markdown]
# Words with highest TF-IDF are much more informative.

# %% [markdown]
# #Manually compute distances between a few people
#
# Let's manually compare the distances between the articles for a few famous people.

# %%
clinton = people[people['name'] == 'Bill Clinton']

# %%
beckham = people[people['name'] == 'David Beckham']
#### up here!

# %% [markdown]
# ##Is Obama closer to Clinton than to Beckham?
#
# We will use cosine distance, which is given by
#
# (1-cosine_similarity)
#
# and find that the article about president Obama is closer to the one about former president Clinton than that of footballer David Beckham.

# %%
graphlab.distances.cosine(obama['tfidf'][0],clinton['tfidf'][0])
# Out:
# 0.8339854936884276

# %%
graphlab.distances.cosine(obama['tfidf'][0],beckham['tfidf'][0])
# Out:
# 0.9791305844747478

# %% [markdown]
# #Build a nearest neighbor model for document retrieval
#
# We now create a nearest-neighbors model and apply it to document retrieval.

# %%
knn_model = graphlab.nearest_neighbors.create(people,features=['tfidf'],label='name')
# Out:
# PROGRESS: Starting brute force nearest neighbors model training.

# %% [markdown]
# #Applying the nearest-neighbors model for retrieval

# %% [markdown]
# ##Who is closest to Obama?

# %%
knn_model.query(obama)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 18.87ms      |
# PROGRESS: | Done         |         | 100         | 194.698ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------+----------------+------+
# | query_label | reference_label |    distance    | rank |
# +-------------+-----------------+----------------+------+
# |      0      |   Barack Obama  |      0.0       |  1   |
# |      0      |    Joe Biden    | 0.794117647059 |  2   |
# |      0      |  Joe Lieberman  | 0.794685990338 |  3   |
# |      0      |   Kelly Ayotte  | 0.811989100817 |  4   |
# ...

# %% [markdown]
# As we can see, president Obama's article is closest to the one about his vice-president Biden, and those of other politicians.

# %% [markdown]
# ##Other examples of document retrieval

# %%
swift = people[people['name'] == 'Taylor Swift']

# %%
knn_model.query(swift)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 17.804ms     |
# PROGRESS: | Done         |         | 100         | 135.698ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+------------------+----------------+------+
# | query_label | reference_label  |    distance    | rank |
# +-------------+------------------+----------------+------+
# |      0      |   Taylor Swift   |      0.0       |  1   |
# |      0      | Carrie Underwood | 0.76231884058  |  2   |
# |      0      |   Alicia Keys    | 0.764705882353 |  3   |
# |      0      |  Jordin Sparks   | 0.769633507853 |  4   |
# ...

# %%
jolie = people[people['name'] == 'Angelina Jolie']

# %%
knn_model.query(jolie)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 24.658ms     |
# PROGRESS: | Done         |         | 100         | 149.909ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+--------------------+----------------+------+
# | query_label |  reference_label   |    distance    | rank |
# +-------------+--------------------+----------------+------+
# |      0      |   Angelina Jolie   |      0.0       |  1   |
# |      0      |     Brad Pitt      | 0.784023668639 |  2   |
# |      0      |   Julianne Moore   | 0.795857988166 |  3   |
# |      0      | Billy Bob Thornton | 0.803069053708 |  4   |
# ...

# %%
arnold = people[people['name'] == 'Arnold Schwarzenegger']

# %%
knn_model.query(arnold)
# Out:
# PROGRESS: Starting pairwise querying...
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | Query points | # Pairs | % Complete. | Elapsed Time |
# PROGRESS: +--------------+---------+-------------+--------------+
# PROGRESS: | 0            | 1       | 0.00169288  | 23.009ms     |
# PROGRESS: | Done         |         | 100         | 151.716ms    |
# PROGRESS: +--------------+---------+-------------+--------------+
# Columns:
# 	query_label	int
# 	reference_label	str
# 	distance	float
# 	rank	int
#
# Rows: 5
#
# Data:
# +-------------+-----------------------+----------------+------+
# | query_label |    reference_label    |    distance    | rank |
# +-------------+-----------------------+----------------+------+
# |      0      | Arnold Schwarzenegger |      0.0       |  1   |
# |      0      |     Jesse Ventura     | 0.818918918919 |  2   |
# |      0      |     John Kitzhaber    | 0.824615384615 |  3   |
# ...
